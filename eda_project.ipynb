# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_palette('Greens_d')

# %%
#reading data from the file
df = pd.read_csv('/workspaces/Data_analysis/data/california_housing_prices.csv')

# %%
#just to understand the data like what are the columns and what is the data is all about(nmubers, alpha numeric)
df.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
# 5    -122.25     37.85                52.0        919.0           213.0
# 6    -122.25     37.84                52.0       2535.0           489.0
# 7    -122.25     37.84                52.0       3104.0           687.0
# 8    -122.26     37.84                42.0       2555.0           665.0
# 9    -122.25     37.84                52.0       3549.0           707.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# ...

# %%
# shape (for rows mand columns)

df.shape

print(f'California Hosuing Dataset contains {df.shape[0]} rows and {df.shape[1]} columns.')
# Out:
# California Hosuing Dataset contains 20640 rows and 10 columns.

# %%
#Checking for duplicate records
print(f'California housing dataset contains {sum(df.duplicated())} duplicate records.')
# Out:
# California housing dataset contains 0 duplicate records.

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 20635    False
# 20636    False
# 20637    False
# 20638    False
# 20639    False
# Length: 20640, dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  str
# dtypes: float64(9), str(1)
# memory usage: 1.6 MB

# %%
#for missing records
df.isna().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
pd.Series(df.isna().sum(), name = 'Missing records')
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# Name: Missing records, dtype: int64

# %%
df[['housing_median_age', 'total_rooms', 'total_bedrooms', 'population', 'households', 'median_income', 'median_house_value']].describe()
# Out:
#        housing_median_age   total_rooms  total_bedrooms    population  \
# count        20640.000000  20640.000000    20433.000000  20640.000000
# mean            28.639486   2635.763081      537.870553   1425.476744
# std             12.585558   2181.615252      421.385070   1132.462122
# min              1.000000      2.000000        1.000000      3.000000
# 25%             18.000000   1447.750000      296.000000    787.000000
# 50%             29.000000   2127.000000      435.000000   1166.000000
# 75%             37.000000   3148.000000      647.000000   1725.000000
# max             52.000000  39320.000000     6445.000000  35682.000000
#
#          households  median_income  median_house_value
# count  20640.000000   20640.000000        20640.000000
# mean     499.539680       3.870671       206855.816909
# std      382.329753       1.899822       115395.615874
# min        1.000000       0.499900        14999.000000
# 25%      280.000000       2.563400       119600.000000
# ...

# %%
# 
# Hist_plot = sns.histplot(data = df, x= 'total_bedrooms', binwidth=250)

for p in Hist_plot.patches:
    Hist_plot.text(p.get_x() + p.get_width()/2, p.get_height(), str(int(p.get_height())), ha = 'center', va = 'bottom')

plt.title('Distribution of Total Bedrooms ')
plt.xlabel('')
plt.ylabel('')
plt.yticks([])
plt.gca().spines[['top', 'right']].set_visible(False)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 4
#       1 #
#       2 # Hist_plot = sns.histplot(data = df, x= 'total_bedrooms', binwidth=250)
#       3
# ----> 4 for p in Hist_plot.patches:
#       5     Hist_plot.text(p.get_x() + p.get_width()/2, p.get_height(), str(int(p.get_height())), ha = 'center', va = 'bottom')
#       6
#       7 plt.title('Distribution of Total Bedrooms ')
#
# NameError: name 'Hist_plot' is not defined

# %%
#Imputing missing values intop bedrooms with median value

df['total_bedrooms'] = df['total_bedrooms'].fillna(df['total_bedrooms'].median())

# %%
#

Hist_plot = sns.histplot(data = df, x= 'median_house_value', binwidth=50000)

for p in Hist_plot.patches:
    Hist_plot.text(p.get_x() + p.get_width()/2, p.get_height(), str(int(p.get_height())), ha = 'center', va = 'bottom')

plt.title('Distribution of median_house_value ')
plt.xlabel('median Value')
plt.ylabel('')
plt.yticks([])
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# how many housing complexes fall in each ocean proximity category

plt.figure(figsize=(8,5))
Count_plot = sns.countplot(data = df, x= 'ocean_proximity', order =df['ocean_proximity'].value_counts().index)

for p in Count_plot.patches:
    Count_plot.text(p.get_x() + p.get_width()/2, p.get_height(), str(int(p.get_height())), ha = 'center', va = 'bottom')

plt.title('Count of Housing complexes by Ocean Proximity')
plt.xlabel('Ocean_proximity')
plt.ylabel('Hosuing complexes')

plt.gca().spines[['top', 'right']].set_visible(False)

plt.show()

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='str')

# %%
#outlier detection using boxplot (without for loop)

fig, axs = plt.subplots(nrows = 3, ncols = 3, figsize = (12,9) )

sns.boxplot(data = df, x = 'housing_median_age', ax = axs[0][0])

axs[0][0].set_title('Housing Median Age')
axs[0][0].set_xlabel('')
axs[0][0].set_ylabel('')
axs[0][0].spines[['top', 'right']].set_visible(False)


sns.boxplot(data = df, x = 'total_rooms', ax = axs[0][1])

axs[0][1].set_title('Total Rooms')
axs[0][1].set_xlabel('')
axs[0][1].set_ylabel('')
axs[0][1].spines[['top', 'right']].set_visible(False)

sns.boxplot(data = df, x = 'total_bedrooms', ax = axs[0][2])

axs[0][2].set_title('Total Bedrooms')
axs[0][2].set_xlabel('')
axs[0][2].set_ylabel('')
axs[0][2].spines[['top', 'right']].set_visible(False)

sns.boxplot(data = df, x = 'households', ax = axs[1][0])

axs[1][0].set_title('Total Housholds')
axs[1][0].set_xlabel('')
axs[1][0].set_ylabel('')
axs[1][0].spines[['top', 'right']].set_visible(False)

sns.boxplot(data = df, x = 'population', ax = axs[1][1])

axs[1][1].set_title('Total Population')
axs[1][1].set_xlabel('')
axs[1][1].set_ylabel('')
axs[1][1].spines[['top', 'right']].set_visible(False)

sns.boxplot(data = df, x = 'median_income', ax = axs[1][2])

axs[1][2].set_title('Total median_income')
axs[1][2].set_xlabel('')
axs[1][2].set_ylabel('')
axs[1][2].spines[['top', 'right']].set_visible(False)

sns.boxplot(data = df, x = 'median_house_value', ax = axs[2][0])

axs[2][0].set_title('Total median_house_value')
axs[2][0].set_xlabel('')
axs[2][0].set_ylabel('')
axs[2][0].spines[['top', 'right']].set_visible(False)

axs[2][1].set_visible(False)
axs[2][2].set_visible(False)

plt.tight_layout()

plt.show()

# %%
#for loop (create a metrics) this works in only one dimensional
#outlier detection using boxplots

cols = ['housing_median_age','total_rooms','total_bedrooms', 'population', 'households', 'median_income', 'median_house_value']

fig, axs = plt.subplots(nrows = 3, ncols = 3, figsize = (12,9))
axs = axs.flatten()

for i, col in enumerate(cols):
       sns.boxplot(data = df, x = col, ax = axs[i])
       axs[i].set_title(col.replace('_', '').title())
       axs[i].set_xlabel('')
       axs[i].set_ylabel('')
       axs[i].set_yticks([])
       axs[i].spines[['top', 'right']].set_visible(False)

for j in range(len(cols), len(axs)):
       axs[j].set_visible(False)

plt.tight_layout()
plt.show()

# %%
axs
# Out:
# array([<Axes: title={'center': 'Housingmedianage'}>,
#        <Axes: title={'center': 'Totalrooms'}>,
#        <Axes: title={'center': 'Totalbedrooms'}>,
#        <Axes: title={'center': 'Population'}>,
#        <Axes: title={'center': 'Households'}>,
#        <Axes: title={'center': 'Medianincome'}>,
#        <Axes: title={'center': 'Medianhousevalue'}>, <Axes: >, <Axes: >],
#       dtype=object)

# %%
#outlier treatment
cols = ['housing_median_age','total_rooms','total_bedrooms', 'population', 'households', 'median_income', 'median_house_value']

for col in cols:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1

    lower_limit = q3 - (1.5*iqr)
    upper_limit=q3 + (1.5*iqr)
   

    df[col] = np.where(df[col] < lower_limit, lower_limit, df[col])
    df[col] = np.where(df[col] > upper_limit, upper_limit, df[col])

plt.show()

# %%
cols = ['housing_median_age','total_rooms','total_bedrooms', 'population', 'households', 'median_income', 'median_house_value']

fig, axs = plt.subplots(nrows = 3, ncols = 3, figsize = (12,9))
axs = axs.flatten()

for i, col in enumerate(cols):
       sns.boxplot(data = df, x = col, ax = axs[i])
       axs[i].set_title(col.replace('_', '').title())
       axs[i].set_xlabel('')
       axs[i].set_ylabel('')
       axs[i].spines[['top', 'right']].set_visible(False)

for j in range(len(cols), len(axs)):
       axs[j].set_visible(False)

plt.tight_layout()
plt.show()

# %%
plt.Figure(figsize = (6,6))
sns.heatmap(df.drop('ocean_proximity', axis = 1).corr(), annot = True, fmt = '.2f', cmap = 'Blues')
plt.show()

# %%
#outlier correlation
fig, axs = plt.subplots(nrows = 1, ncols = 3, figsize = (12, 3))
sns.scatterplot(data = df, x = 'housing_median_age', y = 'median_house_value', ax = axs[0])
axs[0].set_xlabel('Housing Median Age')
axs[0].set_ylabel('Median House Value')
axs[0].spines[['top', 'right']].set_visible(False)

sns.scatterplot(data = df, x = 'median_income', y = 'median_house_value', ax = axs[1])
axs[1].set_xlabel('Median Income')
axs[1].set_ylabel('Median House Value')
axs[1].spines[['top', 'right']].set_visible(False)

sns.scatterplot(data = df, x = 'households', y = 'total_rooms', ax = axs[2])
axs[2].set_xlabel('Households')
axs[2].set_ylabel('Total Rooms')
axs[2].spines[['top', 'right']].set_visible(False)
plt.tight_layout()
plt.show()

# %%
#how median house value changes wrt ocean proximity

sns.boxplot(data = df, x = 'ocean_proximity', y = 'median_house_value')
plt.title('Housing value by Ocean Proximity')
plt.xlabel('Ocean_proximity')
plt.ylabel('median_house_value')

plt.gca().spines[['top','right']].set_visible(False)

plt.show()

# %%
#geospatial distribution
sns.scatterplot(data = df, x = 'longitude', y = 'latitude', hue='median_house_value', palette = 'Blues_d')
plt.title('Geospatial distribution of Housing Vaue')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

plt.gca().spines[['top', 'right']].set_visible(False)

plt.show()
